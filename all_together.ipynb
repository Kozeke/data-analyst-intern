# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df_buildings = pd.read_csv(r'C:\Users\Aidos\Desktop\MAP Vizualization\coordinates.txt', sep='\t')
df_buildings.head()
# Out:
#          lat       long  result
# 0  51.176776  71.411287    89.0
# 1  51.150295  71.427043   114.0
# 2  51.171506  71.426943   112.0
# 3  51.158830  71.491008   119.0
# 4  51.192397  71.403605   101.0

# %%
building_list = df_buildings[['result','lat','long']].values.tolist()
building_list
# Out:
# [[89.0, 51.17677638512565, 71.41128734207481],
#  [114.0, 51.150295369922425, 71.42704255556711],
#  [112.0, 51.17150591615157, 71.42694273940698],
#  [119.0, 51.15883014157789, 71.49100781218098],
#  [101.0, 51.192397104277774, 71.40360538255582],
#  [96.0, 51.19463452824039, 71.4298876772938],
#  [98.0, 51.163798174304304, 71.41131662913381],
#  [97.0, 51.16446309392963, 71.44585411139013],
#  [14.0, 51.11984467349858, 71.4393502506774],
#  [85.0, 51.15900615355994, 71.42639896165028],
#  [85.0, 51.15268450810287, 71.48233051114009],
#  [91.0, 51.15112091604562, 71.50248441138956],
#  [109.0, 51.17460313493397, 71.40420359789712],
#  [74.0, 51.16843966657305, 71.42359139615563],
#  [121.0, 51.1725124089669, 71.43369823676751],
#  [113.0, 51.17980773330543, 71.40950722141709],
#  [114.0, 51.17248330280725, 71.46879006099793],
#  [88.0, 51.15008674005568, 71.42703182673162],
#  [118.0, 51.16448760232304, 71.43941209119994],
#  [100.0, 51.15467882700513, 71.48756414100698],
# ...

# %%
df = pd.read_csv(r'C:\Users\Aidos\Desktop\Котельные в Астане\boiler_data\boiler_data.txt', sep='\t')
df.head()
# Out:
#                    name                 type        power  \
# 0  ж/м Железнодорожный   АО «Астана-Энергия»  5,65 Гкал/ч
# 1       Промышленный к.  АО «Астана-Энергия»  5,11 Гкал/ч
# 2  Интернациональный к.  АО «Астана-Энергия»  2,49 Гкал/ч
# 3           Мичурино к.  АО «Астана-Энергия»  5,11 Гкал/ч
# 4       Пригородный к.   АО «Астана-Энергия»  5,15 Гкал/ч
#
#                    fuel_type        lat       long
# 0  Коммунально-бытовой уголь  51.144162  71.568243
# 1  Коммунально-бытовой уголь  51.122588  71.521517
# 2  Коммунально-бытовой уголь  51.129798  71.590308
# 3  Коммунально-бытовой уголь  51.113914  71.645628
# 4  Коммунально-бытовой уголь  51.042035  71.431250

# %%
a_list = df[['name','type','power','fuel_type','lat','long']].values.tolist()

# %%
a_list
# Out:
# [['ж/м Железнодорожный ',
#   'АО «Астана-Энергия»',
#   '5,65 Гкал/ч',
#   'Коммунально-бытовой уголь',
#   51.14416152809521,
#   71.56824299328223],
#  ['Промышленный к.',
#   'АО «Астана-Энергия»',
#   '5,11 Гкал/ч',
#   'Коммунально-бытовой уголь',
#   51.12258784259301,
#   71.52151684979917],
#  ['Интернациональный к.',
#   'АО «Астана-Энергия»',
#   '2,49 Гкал/ч',
#   'Коммунально-бытовой уголь',
#   51.12979779732024,
#   71.59030776974167],
#  ['Мичурино к.',
#   'АО «Астана-Энергия»',
#   '5,11 Гкал/ч',
#   'Коммунально-бытовой уголь',
#   51.11391428738524,
#   71.64562782364628],
#  ['Пригородный к. ',
#   'АО «Астана-Энергия»',
#   '5,15 Гкал/ч',
#   'Коммунально-бытовой уголь',
#   51.04203526576706,
#   71.43124976084854],
#  ['ҰҚК Пригородный к.',
#   'АО «Астана-Энергия»',
#   '8,18  Гкал/ч',
#   'Коммунально-бытовой уголь',
#   51.04108225167931,
#   71.43689607819375],
#  ['УПТК',
#   'АО «Астана-Энергия»',
#   '4,86 Гкал/ч',
#   'Коммунально-бытовой уголь',
# ...

# %%
import folium
import os

# %%
df_map = folium.Map(location=[51.15304562473745,71.49828940738124]) 


tile = folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = False,
        control = True
       )
tile.add_to(df_map)


airport = folium.Marker(location = [51.025048586132094, 71.46643916918595],
                                               popup = 'Nursultan Nazarbayev International Airport',
                                               icon = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\airplane.png',icon_size=(28,25)))
airport.add_to(df_map)


railway1 = folium.Marker(location = [51.11258859374837, 71.53149993159786],
                                               popup = 'Train Station: Nur-Sultan-Nurly Zhol',
                                            icon = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\train.png',icon_size=(45,34)))
railway1.add_to(df_map)


railway2 = folium.Marker(location = [51.19472810823162, 71.40917243088201], 
                                               popup = 'Train Station: Nur-Sultan - 1',
                                               icon = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\train.png',icon_size=(45,34)))
railway2.add_to(df_map)






CHPP1=folium.Polygon([(51.20474429413205, 71.43670595547445), (51.20200162135731, 71.43795050039475),
                                             (51.200038627832996, 71.42499006708677),(51.203157866065865, 71.42374552216646)], 
                                    radius = 4, popup='CHP plant-1', fill_color='red', color = 'red', fill_opacity=0.8)
CHPP1.add_to(df_map)


CHPP2=folium.Polygon([(51.188755032901504, 71.50195183203901), (51.192903954090454, 71.50540651708937),
                               (51.18882196851718, 71.51694816583783), (51.186280090081006, 71.51868623756874),
                               (51.18381838943954, 71.51575796794799)], 
                            radius = 4, popup='CHP plant-2', fill_color='red', color = 'red', fill_opacity=0.8)
CHPP2.add_to(df_map)


CHPP3=folium.Polygon([(51.211144764543526, 71.42066186377792), (51.2131458930312, 71.43537120382926),
                               (51.21014416768734, 71.43659698216686), (51.21121457281516, 71.44361734900954),
                               (51.209795117157384, 71.4446202585585), (51.20607174688109, 71.41512728885964),
                               (51.207491317304886, 71.41568446083127), (51.20821272157168, 71.42055042938361)], 
                               radius = 4, popup='CHP plant-3 (under construction)', 
                               fill_color='red', color = 'red', opacity = 0.4, fill_opacity=0.5)
CHPP3.add_to(df_map)





private_houses_1=folium.Polygon([(51.13262703931126, 71.46310144409014), (51.13442529237494, 71.46883285866362), 
                                         (51.13669210863505, 71.46732189033297), (51.14720444652653, 71.50398518285925),
                                            (51.16614655995457, 71.4403060957997), (51.16642355136968, 71.44253682569163),
                                            (51.16724066636358, 71.44228283169959), (51.16777386070801, 71.44727436591317),
                                            (51.16711602264089, 71.44930631789394), (51.16647202470743, 71.44895293494076),
                                            (51.164260036475795, 71.45649501635137), (51.166725302418214, 71.45850488204032),
                                            (51.167244653440115, 71.45626310893111), (51.16806867840505, 71.45691465876881),
                                            (51.16608035120926, 71.46317179062277), (51.1615424488807, 71.4596331725652),
                                            (51.16240217283053, 71.45652283714826), (51.16345600613661, 71.45725988345559),
                                            (51.164084596996005, 71.45522563564735), (51.16257781338682, 71.45394317507262),
                                            (51.163824681499136, 71.44970253862677), (51.162733879866984, 71.44872963750107)],
                                        popup = 'Private household, decentralized from central heating, used fuel-Coal',
                                        color = 'yellow',
                                        weight = 1,
                                        fill = True,
                                        fill_color = 'yellow',
                                        fill_opacity = 0.7                                        
)
private_houses_4.add_to(df_map)




private_houses_5=folium.CircleMarker(location = (51.093254622061934, 71.40113543116688),
                                               radius = 7, 
                                               popup = 'Weather station',
                                               weight = 1,
                                               color = 'green',
                                               fill_color = 'green',
                                               opacity = 2,
                                               fill_opacity = 0.8
                                              )
private_houses_5.add_to(df_map)



private_houses_6=folium.Polygon([(51.042832606753834, 71.41960579568506), (51.0462674023104, 71.42081400146166),
                                          (51.04616832523667, 71.42890372709628), (51.046531606804244, 71.43100495453386),
                                          (51.04821587502687, 71.43089989316198), (51.060235148251934, 71.41135847799264),
                                          (51.05765985232462, 71.4087844743816), (51.044021603267915, 71.40820663683628)],
                                        popup = 'Private household, decentralized from central heating, used fuel-Coal',
                                        color = 'yellow',
                                        weight = 1,
                                        fill = True,
                                        fill_color = 'yellow',
                                        fill_opacity = 0.7                                        
)
private_houses_6.add_to(df_map)

prom_pos_1=folium.Polygon([(51.12655666018351, 71.50905541891332), (51.129944627187655, 71.52096544241093),
                                    (51.136195996378774, 71.52463862740154),(51.13403081348734, 71.53243023155888),
                                    (51.13431019763007, 71.53933136666963),(51.1300144796304, 71.541557539286),
                                    (51.127220302227045, 71.5374391199457),(51.1214567773619, 71.53899744091717),
                                    (51.117439349891754, 71.5308719108338),(51.11803325246984, 71.52591867676237),
                                    (51.12026905252942, 71.5243047016155),(51.118766886291084, 71.51957408480571),
                                    (51.120059450870166, 71.51434257915723)],
                                        popup = 'Promyshlennyi Township, used coal',
                                        color = 'orange',
                                        weight = 1,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
)
prom_pos_1.add_to(df_map)



prom_pos_2=folium.Polygon([(51.13202122729394, 71.58762197948208), (51.128358523115295, 71.60598974589209),
                                        (51.12593451503473, 71.60830717436438), (51.123456508616954, 71.60719137547031),
                                        (51.12130161236805, 71.6132853540456), (51.118392342978396, 71.61113958694162),
                                        (51.11957762299304, 71.60392980947228), (51.11812295691604, 71.60272817989404),
                                        (51.11817683425416, 71.60049658210592), (51.12043962572239, 71.59311514326825),
                                        (51.11591393195761, 71.58169966227513), (51.11548289038303, 71.5792105724345),
                                        (51.116452728271234, 71.57285910180676), (51.11747642395789, 71.56985502786118),
                                        (51.12571904149305, 71.57380323933249), (51.12959741145094, 71.58401709074741)],
                                        popup = 'Internatsionalnyi Township, used coal',
                                        color = 'orange',
                                        weight = 1,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
)
prom_pos_2.add_to(df_map)



prom_pos_3=folium.Polygon([(51.12273156860685, 71.6407089465412),(51.118735914522325, 71.6575556415202),
                                     (51.105899051332365, 71.64842499004304),(51.118493742561675, 71.63826553276563),
                                     (51.12273156860685, 71.64058034581618)],
                                        popup = 'Michurinskii Township, used coal',
                                        color = 'orange',
                                        weight = 1,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
)
prom_pos_3.add_to(df_map)



prom_pos_4=folium.Polygon([(51.139869433973594, 71.52533049466919),
                                        (51.149884820592035, 71.53468603924252),
                                        (51.14929257324015, 71.5388917427663),
                                        (51.15645287262068, 71.54421324533529),
                                        (51.1570988600174, 71.55202383759374),
                                        (51.15914442710513, 71.55305380580366),
                                        (51.15855229859106, 71.5594052764314),
                                        (51.16269703859496, 71.56026358327301),
                                        (51.16296616468077, 71.56858915963642),
                                        (51.15123080911686, 71.56704420732156),
                                        (51.14907720876404, 71.57880301105132),
                                        (51.14670813229724, 71.57777304284143),
                                        (51.14476970655378, 71.58524031236325),
                                        (51.14137726561285, 71.58704275673058),
                                        (51.139277058183374, 71.58120627020777),
                                        (51.13437620261133, 71.57828802694637),
                                        (51.13696133411586, 71.5594052764314),
                                        (51.13615349606852, 71.53992171112733),
                                        ],
                                        popup = 'Zheleznodorozhnyi Township, used coal',
                                        color = 'orange',
                                        weight = 1,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
)
prom_pos_4.add_to(df_map)


prom_pos_5=folium.Polygon([(51.046425159701414, 71.43462838265171),
                                        (51.04164986289185, 71.44230232285754),
                                        (51.03910118697396, 71.4355335144377),
                                        (51.03949710699427, 71.432542645601),
                                        (51.037641202662265, 71.43210975626292),
                                        (51.03769069440929, 71.42246813961837),
                                        (51.037789677741564, 71.4193198570599),
                                    (51.04625197100784, 71.42093335209022),
                                    (51.046054040283074, 71.4252228876586),
                                    (51.046103523043556, 71.42872535248051)],
                                        popup = 'Prigorodnyy Township',
                                        color = 'orange',
                                        weight = 1,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
)
prom_pos_5.add_to(df_map)




def color_set(a):
    a = str(a)
    if a == 'Коммунально-бытовой уголь':
       icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\grey_triangle.png',icon_size=(15,15))
    elif a == 'Автономное (уголь)':
        icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\grey_triangle.png',icon_size=(15,15))
    elif a == 'сжиженный газ':
       icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\green_triangle.png',icon_size=(15,15)) 
    elif a == 'природный газ':
       icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\green_triangle.png',icon_size=(15,15))
    elif a == 'Автономное (газ)':
       icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\green_triangle.png',icon_size=(15,15)) 
    elif a == 'Электричество':
       icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\green_triangle.png',icon_size=(15,15))
    else:
        icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\blue_triangle.png',icon_size=(15,15))
    return icon_triangle


# grey_icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\grey_triangle.png',icon_size=(15,15))
# blue_icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\blue_triangle.png',icon_size=(15,15))
# green_icon_triangle = folium.features.CustomIcon(r'C:\Users\Aidos\Desktop\Котельные в Астане\green_triangle.png',icon_size=(15,15))

for i in a_list:
    boilers = folium.Marker(location=[i[4],i[5]], popup= str(i[0]) + "\nтип:" +str(i[1]) + "\nтопливо: " + str(i[3]), 
                            icon = color_set(i[3])).add_to(df_map)

# boilers.add_to(df_map)


#here we are adding the building location with energy efficiency indications
def color_set(a):
    if a<110.0:
       colors = 'green'
    elif a>120:
       colors = 'red'
    else:
        colors = 'yellow'
    return colors

for i in building_list:
    buildings = folium.CircleMarker(location=[i[1],i[2]],
                                     radius = 7, 
                                    popup = str(i[0])+"%",
                                    weight = 1,
                                    color = color_set(i[0]),
                                    fill_color = color_set(i[0]),
                                    opacity = 2,
                                    fill_opacity = 0.8).add_to(df_map)


city_area=folium.Polygon([(51.27911413965197, 71.59479805153464), (51.25336508938536, 71.62257580814124),
                          (51.21986975383689, 71.57525074133001), (51.20117906951094, 71.58759641093293),
                          (51.189574139248926, 71.62051819654074), (51.141834268146106, 71.65343998214857),
                          (51.14247973091809, 71.68430415615589), (51.132151243519715, 71.71619713596347),
                          (51.114070830542325, 71.70693788376127), (51.10502797015186, 71.74191728096957),
                          (51.09792162425666, 71.73471564036787), (51.10438198384622, 71.72648519396591),
                          (51.09727553864339, 71.70693788376127), (51.09508673412946, 71.7093052447448),
                          (51.092910944886604, 71.69948948274433), (51.08928440197643, 71.69660249392065),
                          (51.09377691152176, 71.695371886772), (51.094664668263874, 71.69307489757634),
                          (51.09144646898372, 71.68759746180213), (51.09311108278039, 71.68600723851283),
                          (51.09244524445201, 71.6819433345513), (51.08967081488925, 71.67999972830883),
                          (51.09044767194438, 71.67805612206637), (51.0864522680734, 71.67381552662826),
                          (51.091002561851575, 71.62964265748127), (51.08944885333382, 71.60614269109507),
                          (51.09168281900205, 71.59890943110985), (51.088532640334556, 71.58694955972905),
                          (51.09410588735176, 71.57704730062882), (51.09055201032214, 71.56926673648702),
                          (51.09097558823455, 71.56676185169685), (51.09291189500085, 71.56656916825146),
                          (51.09260935241282, 71.5636789165705), (51.093577481727166, 71.55915085560366),
                          (51.09292794345865, 71.55553504496032), (51.09944763797841, 71.54255825295772),
                          (51.09999090444147, 71.53325821596378), (51.09768197823305, 71.51271162862633),
                          (51.0884644006595, 71.50179791551038), (51.076747265009026, 71.46463427607678),
                          (51.06388142750635, 71.44752497372492), (51.05626396671297, 71.45446023548018),
                          (51.050106739701036, 71.46915297960449), (51.04674790717991, 71.4709339182862),
                            (51.037685231614844, 71.49057869350989),
                            (51.032003416201796, 71.48847746537784),
                            (51.02262028914105, 71.47229800876099),
                            (51.008740351152234, 71.45506793614383),
                            (51.00543499180923, 71.44246056735149),
                            (51.00821150948526, 71.4359467601421),
                            (51.0090047697246, 71.3958133028198),
                            (51.017200997811486, 71.34811542422209),
