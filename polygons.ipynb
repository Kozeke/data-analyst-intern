# %%
import pandas as pd
import folium

# %%
df_map_houses = folium.Map(location=[51.13262703931126, 71.46310144409014]) 


private_houses_1 = folium.FeatureGroup(name='map')

private_houses_1.add_child(folium.Polygon([(51.13262703931126, 71.46310144409014), (51.13442529237494, 71.46883285866362), 
                                         (51.13669210863505, 71.46732189033297), (51.14720444652653, 71.50398518285925),
                                         (51.138993907955175, 71.52507930999728), (51.136651937940044, 71.52292476285372),
                                         (51.13617591324752, 71.52450274104338), (51.13003459711195, 71.5209469823736),
                                         (51.12671330265032, 71.50874004249334), (51.13394135883085, 71.50390023133582),
                                         (51.127378905264344, 71.48058320691445), (51.12759319541547, 71.4799265733402),
                                         (51.12675251296806, 71.4782981220761), (51.12686790166097, 71.47677473218386),
                                         (51.13107221563946, 71.4788621599881), (51.13214549058507, 71.47427546759673),
                                         (51.13262704818271, 71.47388193207955), (51.12994998085171, 71.46495150746732)],
                                        tooltip = 'Микрорайон Юго-Восток (левая сторона)',
                                        color = 'orange',
                                        weight = 2,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
))
df_map_houses.add_child(private_houses_1)




private_houses_2 = folium.FeatureGroup(name='map')

private_houses_2.add_child(folium.Polygon([(51.136551693265176, 71.41704124748036), (51.14408964341541, 71.42165231424269),
                                           (51.14434887720596, 71.42121942518904), (51.14577701672584, 71.42205702266095),
                                           (51.146881795961626, 71.42334585144275), (51.14831362129891, 71.42401019062568),
                                           (51.150818890827345, 71.4276545696058), (51.14672834961577, 71.43696374015144),
                                           (51.145097719203086, 71.43886614132605), (51.14401998973326, 71.43966930404842),
                                           (51.14153412047461, 71.43967821735474), (51.13938341234375, 71.4406444148923),
                                           (51.138900275264184, 71.43766710801616), (51.13346739280341, 71.43549355044875)],
                                        tooltip = 'Микрорайон Чубары',
                                        color = 'orange',
                                        weight = 2,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
))
df_map_houses.add_child(private_houses_2)




private_houses_3 = folium.FeatureGroup(name='map')

private_houses_3.add_child(folium.Polygon([(51.083718714539316, 71.38954115599252), (51.08234013452997, 71.39931440175747),
                                          (51.07967903832841, 71.39834473246486), (51.081763042327864, 71.38890321566844)],
                                        tooltip = ' ',
                                        color = 'orange',
                                        weight = 2,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
))
df_map_houses.add_child(private_houses_3)

private_houses_4 = folium.FeatureGroup(name='map')

private_houses_4.add_child(folium.Polygon([(51.16608878458068, 71.44040607837638), (51.16662806819094, 71.44455345175862),
                                          (51.165816620364566, 71.44475439039148), (51.16563517666161, 71.44300220551294),
                                          (51.165398290752925, 71.44283341706134), (51.16518156428142, 71.44060701700924)],
                                        tooltip = ' ',
                                        color = 'orange',
                                        weight = 2,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
))
df_map_houses.add_child(private_houses_4)

private_houses_5 = folium.FeatureGroup(name='map')

private_houses_5.add_child(folium.Polygon([(51.09425520046857, 71.39940300415068), (51.093406765218056, 71.39909846358167),
                                          (51.09357596308582, 71.3979779104623), (51.09441213476266, 71.39831759032775)],
                                        tooltip = 'Технопарк (Назарбаев Университет)',
                                        color = 'orange',
                                        weight = 2,
                                        fill = True,
                                        fill_color = 'orange',
                                        fill_opacity = 0.7                                        
))
df_map_houses.add_child(private_houses_5)

df_map_houses.save(r'C:\Users\Aidos\Desktop\Котельные в Астане\polygons.html')
